# %% [markdown]
# # Product Optimization & Revenue Contribution Analysis for Afficionado Coffee Roasters

# %% [markdown]
# ## Import Library's

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import mysql.connector as mc
from sqlalchemy import create_engine,text

# %% [markdown]
# ## Load csv file

# %%
df1 = pd.read_csv(r'E:\Product Optimization & Revenue Contribution Analysis for Afficionado Coffee Roasters\row_data\Afficionado Coffee Roasters - Transactions.csv')

# %%
df1['store_id'].unique()
# Out:
# array([5, 8, 3])

# %% [markdown]
# ## Check shape
# * rows 149116
# * Columns 11

# %%
df.shape
# Out:
# (149116, 11)

# %% [markdown]
# ## Check Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   year              149116 non-null  int64
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 12.5+ MB

# %% [markdown]
# ## Check dtypes

# %%
df.head(5)
# Out:
#    transaction_id  year transaction_time  transaction_qty  store_id  \
# 0               1  2025         07:06:11                2         5
# 1               2  2025         07:08:56                2         5
# 2               3  2025         07:14:04                2         5
# 3               4  2025         07:20:24                1         5
# 4               5  2025         07:22:41                2         5
#
#     store_location  product_id  unit_price    product_category  \
# 0  Lower Manhattan          32         3.0              Coffee
# 1  Lower Manhattan          57         3.1                 Tea
# 2  Lower Manhattan          59         4.5  Drinking Chocolate
# 3  Lower Manhattan          22         2.0              Coffee
# 4  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail  revenue  indian_price  \
# 0  Gourmet brewed coffee                  Ethiopia Rg      6.0        283.50
# ...

# %%
df.dtypes
# Out:
# transaction_id               int64
# year                         int64
# transaction_time            object
# transaction_qty              int64
# store_id                     int64
# store_location      string[python]
# product_id                   int64
# unit_price                 float64
# product_category    string[python]
# product_type        string[python]
# product_detail      string[python]
# revenue                    float64
# indian_price               float64
# hour                         int32
# dtype: object

# %% [markdown]
# ## Change Datatypes

# %%
df['transaction_time'] = pd.to_datetime(df['transaction_time'], format='%H:%M:%S').dt.time

# %%
df['store_location'] = df['store_location'].astype('string')

# %%
df = df.astype({
    'product_category' : 'string',
    'product_type' : 'string',
    'product_detail' : 'string'
})

# %% [markdown]
# ## Create new columns

# %%
df['revenue'] = df.transaction_qty * df.unit_price

# %%
df['indian_price'] = df.unit_price * 94.5

# %%
df['hour'] = pd.to_datetime(df['transaction_time'],format='%H:%M:%S').dt.hour

# %% [markdown]
# ## Check null values

# %%
df.isnull().sum()
# Out:
# transaction_id      0
# year                0
# transaction_time    0
# transaction_qty     0
# store_id            0
# store_location      0
# product_id          0
# unit_price          0
# product_category    0
# product_type        0
# product_detail      0
# revenue             0
# indian_price        0
# dtype: int64

# %% [markdown]
# ## Check duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        transaction_id      year  transaction_qty       store_id  \
# count   149116.000000  149116.0    149116.000000  149116.000000
# mean     74737.371872    2025.0         1.438276       5.342063
# std      43153.600016       0.0         0.542509       2.074241
# min          1.000000    2025.0         1.000000       3.000000
# 25%      37335.750000    2025.0         1.000000       3.000000
# 50%      74727.500000    2025.0         1.000000       5.000000
# 75%     112094.250000    2025.0         2.000000       8.000000
# max     149456.000000    2025.0         8.000000       8.000000
#
#           product_id     unit_price        revenue   indian_price
# count  149116.000000  149116.000000  149116.000000  149116.000000
# mean       47.918607       3.382219       4.686367     319.619735
# std        17.930020       2.658723       4.227099     251.249287
# min         1.000000       0.800000       0.800000      75.600000
# ...

# %%
df.head(10)
# Out:
#    transaction_id  year transaction_time  transaction_qty  store_id  \
# 0               1  2025         07:06:11                2         5
# 1               2  2025         07:08:56                2         5
# 2               3  2025         07:14:04                2         5
# 3               4  2025         07:20:24                1         5
# 4               5  2025         07:22:41                2         5
# 5               6  2025         07:22:41                1         5
# 6               7  2025         07:25:49                1         5
# 7               8  2025         07:33:34                2         5
# 8               9  2025         07:39:13                1         5
# 9              10  2025         07:39:34                2         5
#
#     store_location  product_id  unit_price    product_category  \
# 0  Lower Manhattan          32        3.00              Coffee
# 1  Lower Manhattan          57        3.10                 Tea
# ...

# %% [markdown]
# ## Let's analysis

# %%
df['product_category'].nunique()
# Out:
# 9

# %% [markdown]
# ## Let's Convert csv into database

# %% [markdown]
# * Create database coffee_roasters_db;

# %%
conn = mc.connect(
    host='localhost',
    user='root',
    password='qwe99ewq'
)
cursor = conn.cursor()
cursor.execute('CREATE DATABASE coffee_roasters_db')
for i in cursor.fetchall():
    print(i)

# %%
engine = create_engine('mysql+pymysql://root:qwe99ewq@localhost/coffee_roasters_db')

# %%
df.to_sql('coffee_roasters_tables',index=False,con=engine,if_exists='replace')
# Out:
# C:\Users\Mohd Noman\AppData\Local\Temp\ipykernel_14328\2307600253.py:1: UserWarning: the 'timedelta' type is not supported, and will be written as integer values (ns frequency) to the database.
#   df.to_sql('coffee_roasters_tables',index=False,con=engine,if_exists='replace')
# 149116

# %% [markdown]
# * I have saved df in database

# %% [markdown]
# # Analysis & Visualization

# %%
df=pd.read_sql('SELECT * FROM coffee_roasters_tables',con=engine)

# %%
df.shape
# Out:
# (149116, 14)

# %%
df.head(2)
# Out:
#    transaction_id  year transaction_time  transaction_qty  store_id  \
# 0               1  2025  0 days 07:06:11                2         5
# 1               2  2025  0 days 07:08:56                2         5
#
#     store_location  product_id  unit_price product_category  \
# 0  Lower Manhattan          32         3.0           Coffee
# 1  Lower Manhattan          57         3.1              Tea
#
#             product_type            product_detail  revenue  indian_price  \
# 0  Gourmet brewed coffee               Ethiopia Rg      6.0        283.50
# 1        Brewed Chai tea  Spicy Eye Opener Chai Lg      6.2        292.95
#
#    hour
# 0     7
# 1     7

# %%
print(f'''
store_id
{df['store_id'].unique()}
{df['store_id'].nunique()}
-------------------------------------------------------------------------------------------------------------------------------------------
store_location
{df['store_location'].unique()}
{df['store_location'].nunique()}
-------------------------------------------------------------------------------------------------------------------------------------------
product_id
{df['product_id'].unique()}
{df['product_id'].nunique()}
-------------------------------------------------------------------------------------------------------------------------------------------
product_category
{df['product_category'].unique()}
{df['product_category'].nunique()}
-------------------------------------------------------------------------------------------------------------------------------------------
product_type
{df['product_type'].unique()}
{df['product_type'].nunique()}
-------------------------------------------------------------------------------------------------------------------------------------------
product_detail
{df['product_detail'].unique()}
{df['product_detail'].nunique()}
''')
# Out:
# store_id
# [5 8 3]
# 3
# -------------------------------------------------------------------------------------------------------------------------------------------
# store_location
# ['Lower Manhattan' "Hell's Kitchen" 'Astoria']
# 3
# -------------------------------------------------------------------------------------------------------------------------------------------
# product_id
# [32 57 59 22 77 28 39 58 56 33 51 87 47 79 42 61 69 40 43 76 45 71 38 26
#  27 29 54 55 24 60 78 44 48 23 46 25 34 36 74 53 41 37 50 72 35 70 73 75
#  31 49 52 30 64 12 63  6  9 65 84 19  7  1 17 10  4 15 16  3 20 83 18 21
#  13 11  5  2 81 14  8 82]
# 80
# -------------------------------------------------------------------------------------------------------------------------------------------
# product_category
# ['Coffee' 'Tea' 'Drinking Chocolate' 'Bakery' 'Flavours' 'Loose Tea'
#  'Coffee beans' 'Packaged Chocolate' 'Branded']
# 9
# ...

# %% [markdown]
# ## Pareto 80/20 analysis karo

# %%
quary='''
SELECT product_id,
product_detail,
ROUND(SUM(revenue),2) AS total_revenue
FROM coffee_roasters_tables
GROUP BY product_id,
product_detail
ORDER BY total_revenue DESC;'''
pa_revenue=pd.read_sql(quary,con=engine)
pa_revenue
# Out:
#     product_id                product_detail  total_revenue
# 0           61  Sustainably Grown Organic Lg       21151.75
# 1           59             Dark chocolate Lg       21006.00
# 2           39                      Latte Rg       19112.25
# 3           41                 Cappuccino Lg       17641.75
# 4           55       Morning Sunrise Chai Lg       17384.00
# ..         ...                           ...            ...
# 75          11                   Lemon Grass        1360.40
# 76          10  Guatemalan Sustainably Grown        1340.00
# 77          18         Spicy Eye Opener Chai        1335.90
# 78          14                     Earl Grey        1270.90
# 79          19                Dark chocolate         755.20
#
# [80 rows x 3 columns]

# %%
df['product_detail'].unique()
df['product_detail'].nunique()
# Out:
# 80

# %%
df['product_id'].unique()
df['product_id'].nunique()
# Out:
# 80
